# %%
f = open("25_sample.text" , "r")

data = f.read()
print(data)
print(type(data))

f.close()
# Out:
# This is Python Code.
# This is Laptop,
# This is Mobile.
#
# <class 'str'>

# %%
f = open("25_sample.text" , "r")

data = f.readline()
print(data)

data = f.readline()
print(data)

print(type(data))

f.close()
# Out:
# This is Python Code.
#
# This is Laptop,
#
# <class 'str'>

# %%
# write
f = open("25_sample.text" , "w")

f.write("change the text \ninside this file.")

f.close()

# %%
f = open("25_sample.text" , "w")

f.write("123")

f.close()

# %%
# append

f = open("25_sample.text" , "a")
f.write("\nThis is new text - added")

f.close()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
with open("25_sample.text" , "r") as f:
    data = f.read()
    print(data)
# Out:
# 123
# This is new text - added

# %%
# qustion - word search

data = True
word = "Python"
line = 1

with open("26_sample2.txt" , "r") as f:
    while data:
        data = f.readline()
        if word in data:
            print(f'{word} found at {line}')
            break
        
        #print(data)
        line +=1
# Out:
# Python found at 3

# %% [markdown]
# ![image.png](attachment:image.png)
