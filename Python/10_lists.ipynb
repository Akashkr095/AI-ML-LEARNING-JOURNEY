# %%
list = [1,2,3,4,5,6,7,8,9]
print(list)
print(len(list))
print(type(list))
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]
# 9
# <class 'list'>

# %%
my_list = ["apple", 100 , "india" , 20.9 , "google"]
print(my_list)
# Out:
# ['apple', 100, 'india', 20.9, 'google']

# %%
my_list
print(my_list[0])
print(my_list[1])
print(my_list[2])
print(my_list[3])
print(my_list[4])
# Out:
# apple
# 100
# india
# 20.9
# google

# %%
my_list
print(my_list[-1])
print(my_list[-4])
# Out:
# google
# 100

# %%
# modify

lists = [1,2,3,4,5]
print(lists)
lists[0] = 100
print(lists)
# Out:
# [1, 2, 3, 4, 5]
# [100, 2, 3, 4, 5]

# %%
# slicing
lists = [1,2,3,4,5,6,7,8]
print(lists[1:4])
print(list[1:7:2])
print(list[-6:-2])
# Out:
# [2, 3, 4]
# [2, 4, 6]
# [4, 5, 6, 7]

# %%
# list methods

lists = [1,2,3]

print(len(lists))

lists.append(100)
print(lists)

lists.insert(1,100)
print(lists)

lists.sort()
print(lists)

lists.reverse()
print(lists)
# Out:
# 3
# [1, 2, 3, 100]
# [1, 100, 2, 3, 100]
# [1, 2, 3, 100, 100]
# [100, 100, 3, 2, 1]

# %%
## loopos in lists
my_list = ["apple", 100 , "india" , 20.9 , "google"]

for item in my_list:
    print(item)
# Out:
# apple
# 100
# india
# 20.9
# google

# %%
lst = [1,2,3,4,100,6,7,8,9]

val = 100
idx = 0 

for i in lst:
    if i == val:
        print(f'The {val} found at index {idx}')
    idx += 1
# Out:
# The 100 found at index 4
