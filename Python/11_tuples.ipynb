# %%
tuple = (10,20,30)
print(tuple)
# Out:
# (10, 20, 30)

# %%
tuple = (7)    #wrong
print(type(tuple))

tuple = (7,)   #correct
print(type(tuple))
# Out:
# <class 'int'>
# <class 'tuple'>

# %%
tuple = (10,20,30)
print(tuple[0])
print(tuple[1])
print(tuple[1:2])
# Out:
# 10
# 20
# (20,)

# %%
tuple = (10,20,30)

for val in tuple:
    print(val)
# Out:
# 10
# 20
# 30

# %%
tuple = (10,20,30)
sum = 0

for i in tuple:
    sum = sum + i

print(f'The sum is {sum}')
# Out:
# The sum is 60
