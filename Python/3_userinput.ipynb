# %%
a  = input("enter a name:")
print("welcome", a)
# Out:
# welcome Akash

# %%
a = input("enter a number:")
print("you entered:", a)
b = input("enter another number:")
print("you entered:", b)

sum = a+b
print("the sum is:", sum) # this will concatenate the inputs as strings so we need to convert them to integers.
# Out:
# you entered: 10
# you entered: 5
# the sum is: 105

# %%
a = int(input("enter a number:"))
print("you entered:", a)
b = int(input("enter another number:"))
print("you entered:", b)

sum = a+b
print("the sum is:", sum)
# Out:
# you entered: 10
# you entered: 5
# the sum is: 15

# %%
# avarage of 2 num
num1 = float(input("enetr the number:"))
print("you enterd:",num1)
num2 = float(input("enter the second num:"))
print("you enterd:",num2)

avg = (num1+num2)/2

print("Avarage = ", avg)
# Out:
# you enterd: 15.5
# you enterd: 4.5
# Avarage =  10.0
