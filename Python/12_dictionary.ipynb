# %%
dic = {
    "name": "akash",
    "age": 11.2,
    "subject": ["maths", "science"]
}
print(dic)
# Out:
# {'name': 'akash', 'age': 11.2, 'subject': ['maths', 'science']}

# %%
dic = {
    "name": "akash",
    "age": 11.2,
    "subject": ["maths", "science"],

    3.14 : "pi value"}
print(dic)
# Out:
# {'name': 'akash', 'age': 11.2, 'subject': ['maths', 'science'], 3.14: 'pi value'}

# %%
dic["age"]
# Out:
# 11.2

# %%
# dectionary methods
dic.keys()
# Out:
# dict_keys(['name', 'age', 'subject', 3.14])

# %%
dic.values()
# Out:
# dict_values(['akash', 11.2, ['maths', 'science'], 'pi value'])

# %%
dic.items()
# Out:
# dict_items([('name', 'akash'), ('age', 11.2), ('subject', ['maths', 'science']), (3.14, 'pi value')])

# %%
print(dic["age"])
print(dic.get("age"))  # Returns None if key doesn't exist
# Out:
# 11.2
# 11.2

# %%
dic.update({"city": "bihar"})
print(dic)
# Out:
# {'name': 'akash', 'age': 11.2, 'subject': ['maths', 'science'], 3.14: 'pi value', 'city': 'bihar'}

# %%
# loops

dic
# Out:
# {'name': 'akash',
#  'age': 11.2,
#  'subject': ['maths', 'science'],
#  3.14: 'pi value',
#  'city': 'bihar'}

# %%
for key,value in dic.items():
    print(f"key is {key} and value is {value}")
# Out:
# key is name and value is akash
# key is age and value is 11.2
# key is subject and value is ['maths', 'science']
# key is 3.14 and value is pi value
# key is city and value is bihar
