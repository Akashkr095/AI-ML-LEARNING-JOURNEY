# %% [markdown]
# ![image.png](attachment:image.png)

# %%
with open("names.txt" , "x") as f:
    #data = f.readline()
    for i in range(1,6):
        name = input("Enter the name : ")
        f.write(name + "\n")

# %%
data = True
with open("names.txt" , "r") as file:
    while data:
        data = file.readline()
        print(data , end="")
# Out:
# Akash
# Ankit
# Amar
# Tushar
# Suvansh

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
with open("log.txt" , "a") as f:
    f.write("Program run successfully")

with open("log.txt" , "r") as f:
    data = f.read()
    print(data)
# Out:
# This is Python.
# This is a Old Text.
# Program run successfully

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
list = [i*5 for i in range(1,6)]
print(list)
# Out:
# [5, 10, 15, 20, 25]

# %%
new = [i for i in list if i > 15]
print(new)
# Out:
# [20, 25]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
try:
    with open("data.txt" , "r") as f:
        print(f.read())
except:
    print("File noit Found")
# Out:
# this is data file
