# %% [markdown]
# # Variables

# %%
name = "Akash"
age = 21
height = 5.9
print("Name:", name)
print("Age:", age)
print("Height:", height)
# Out:
# Name: Akash
# Age: 21
# Height: 5.9

# %% [markdown]
# ## Data types

# %%
x = 10
print(type(x)) # int
PI = 3.14
print(type(PI)) # float'
name = "akash"
print(type(name)) # string'
isStudent = True
print(type(isStudent)) # bool'
empty_var = None
print(type(empty_var)) # NoneType'
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>
# <class 'NoneType'>

# %% [markdown]
# comment

# %%
# this is a comment

'''
This is a multi-line comment
file created for variable demonstration

'''
# Out:
# '\nThis is a multi-line comment\nfile created for variable demonstration\n\n'

# %%
a = 19
b= 39
sum = a+b
print("Sum:", sum)
# Out:
# Sum: 58

# %% [markdown]
# # type conversion

# %%
# Type conversion - Implicit,
a = 5
b = 3.0
print(a + b) # Python converts ans in float by default
# Out:
# 8.0

# %%
# Type Casting - Explicitly
x = 10 # int
y = float(x) # convert to float
print(type(y))
# Out:
# <class 'float'>

# %%
a = 5.6
z = str(a) # convert to string
print(type(z))
# Out:
# <class 'str'>
