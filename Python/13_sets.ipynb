# %%
setts = {1,2,3,4,4,4,4}
print(setts)
print(type(setts))
print(len(setts))
# Out:
# {1, 2, 3, 4}
# <class 'set'>
# 4

# %%
empty_set = {}
print(type(empty_set))
emptyy_set = set()
print(type(emptyy_set))
# Out:
# <class 'dict'>
# <class 'set'>

# %%
# set methods

setts
# Out:
# {1, 2, 3, 4}

# %%
setts.add(1000)
print(setts)
# Out:
# {1, 2, 3, 4, 1000}

# %%
setts.remove(1)
print(setts)
# Out:
# {2, 3, 4, 1000}

# %%
setts.pop()
# Out:
# 2

# %%
setts
# Out:
# {3, 4, 1000}

# %%
setts.clear()
print(setts)
# Out:
# set()

# %%
set1 = {1,2,3,4,5}
set2 = {4,5,6,7,8}

set1.union(set2)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8}

# %%
set1 = {1,2,3,4,5}
set2 = {4,5,6,7,8}
set1.intersection(set2)
# Out:
# {4, 5}

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %%
info = [
("Alice", "Math"),
("Bob", "Science"),
("Alice", "Science"),
("Charlie", "Math"),
("Bob", "Math"),
("Alice", "English"),
("Charlie", "English"),
]

# %%
for tuple in info:
    print(tuple[0])
    print(tuple[1])
# Out:
# Alice
# Math
# Bob
# Science
# Alice
# Science
# Charlie
# Math
# Bob
# Math
# Alice
# English
# Charlie
# English

# %%
# question 1

unique_set = set()
for tup in info:
    #print(tup)
    unique_set.add(tup[1])
print(unique_set)
# Out:
# {'Math', 'Science', 'English'}

# %%
# question 2

for name,sub in info:
    if sub == "English":
        print(name)
# Out:
# Alice
# Charlie
